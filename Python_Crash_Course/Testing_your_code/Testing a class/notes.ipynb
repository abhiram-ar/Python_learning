# %% [markdown]
# ## Testing a class
#
# ### A variety of assert methods
# assert methods test whether a condition you believe is
# true at a specific point in your code is indeed true.
#
# If the condition you assume is true is actually not true, Python raises an exception
#
#
# ![image.png](attachment:image.png)
